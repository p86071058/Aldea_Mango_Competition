# %%
# %cd drive/My Drive/project/mango/train_dev
# !ls
# Out:
# /content/drive/My Drive/project/mango/train_dev
# C2_TrainDev.rar  Dev  dev.csv  install_yolov4.ipynb  Train  train.csv

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14654, done.
# remote: Total 14654 (delta 0), reused 0 (delta 0), pack-reused 14654
# Receiving objects: 100% (14654/14654), 13.24 MiB | 4.22 MiB/s, done.
# Resolving deltas: 100% (9973/9973), done.
# Checking out files: 100% (2027/2027), done.

# %%
# !sed -i "s/GPU=0/GPU=1/g" darknet/Makefile
# !sed -i "s/CUDNN=0/CUDNN=1/g" darknet/Makefile
# !sed -i "s/CUDNN_HALF=0/CUDNN_HALF=1/g" darknet/Makefile
# !sed -i "s/OPENCV=0/OPENCV=1/g" darknet/Makefile

# %%
# !head darknet/Makefile
# Out:
# GPU=1
# CUDNN=1
# CUDNN_HALF=1
# OPENCV=1
# AVX=0
# OPENMP=0
# LIBSO=0
# ZED_CAMERA=0
# ZED_CAMERA_v2_8=0

# %%
ls
# Out:
# C2_TrainDev.rar  Dev/     install_yolov4.ipynb  train.csv
# darknet/         dev.csv  Train/

# %%
# %cd darknet
# !ls
# Out:
# /content/drive/My Drive/project/mango/train_dev/darknet
# 3rdparty   CMakeLists.txt	   image_yolov4.sh	  obj
# backup	   DarknetConfig.cmake.in  include		  README.md
# build	   darknet_images.py	   json_mjpeg_streams.sh  results
# build.ps1  darknet.py		   LICENSE		  scripts
# build.sh   darknet_video.py	   Makefile		  src
# cfg	   data			   net_cam_v3.sh	  video_yolov3.sh
# cmake	   image_yolov3.sh	   net_cam_v4.sh	  video_yolov4.sh

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  results
# backup		darknet_images.py	LICENSE		       scripts
# build		darknet.py		Makefile	       src
# build.ps1	darknet_video.py	mango_dectection       video_yolov3.sh
# build.sh	data			net_cam_v3.sh	       video_yolov4.sh
# cfg		image_yolov3.sh		net_cam_v4.sh
# cmake		image_yolov4.sh		obj
# CMakeLists.txt	include			README.md

# %%
import os
import shutil
# if not os.path.exists('mango_dectection'):
#  os.mkdir('mango_dectection')
# if not os.path.exists('mango_dectection/cfg'):
#  os.mkdir('mango_dectection/cfg') 
#  os.mkdir('mango_dectection/weights')

# if not os.path.exists('face_dection/cfg/mango.data'):
#   shutil.copyfile('cfg/coco.data', 'mango_dection/cfg/mango.data')

# if not os.path.exists('face_dection/cfg/mango.names'):
#   shutil.copyfile('cfg/coco.names', 'mango_dection/cfg/mango.names')

# if not os.path.exists(“Face_detection/cfg/face.data”):
#  shutil.copyfile(“darknet/cfg/coco.data”, “Face_detection/cfg/face.data”)
# if not os.path.exists(“Face_detection/cfg/face.names”):
#  shutil.copyfile(“darknet/cfg/coco.names”, “Face_detection/cfg/face.names”)

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  results
# backup		darknet_images.py	LICENSE		       scripts
# build		darknet.py		Makefile	       src
# build.ps1	darknet_video.py	mango_dectection       video_yolov3.sh
# build.sh	data			net_cam_v3.sh	       video_yolov4.sh
# cfg		image_yolov3.sh		net_cam_v4.sh
# cmake		image_yolov4.sh		obj
# CMakeLists.txt	include			README.md

# %%
# !head mango_detection/cfg/mango.data
# Out:
# classes= 80
# train  = /home/pjreddie/data/coco/trainvalno5k.txt
# valid  = coco_testdev
# #valid = data/coco_val_5k.list
# names = data/coco.names
# backup = /home/pjreddie/backup/
# eval=coco

# %%
# !head mango_detection/cfg/mango.names
# Out:
# person
# bicycle
# car
# motorbike
# aeroplane
# bus
# train
# truck
# boat
# traffic light

# %%
# !cd ..; mkdir mango_detection
# !cd mango_detection
# Out:
# /bin/bash: line 0: cd: mango_detection: No such file or directory
