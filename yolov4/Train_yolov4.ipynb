# %%
# !make

# %%
# !nvidia-smi
# Out:
# Fri Jan  8 07:16:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8    10W /  70W |     10MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %cd drive/My Drive/project/mango/darknet/
# Out:
# /content/drive/My Drive/project/mango/darknet

# %%
# !chmod +x ./darknet

# %% [markdown]
# #calc_anchors

# %%
# !./darknet detector calc_anchors ../mango_detection/cfg/mango.data -num_of_clusters 6 -width 416 -height 416 -showpause
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#
#  num_of_clusters = 6, width = 416, height = 416
#  read labels from 43370 images
#  loaded 	 image: 43370 	 box: 43370
#  all loaded.
#
#  calculating k-means++ ...
#
#  iterations = 59
#
#
# counters_per_class = 0, 2579, 502, 23587, 15045, 1657
#
#  avg IoU = 64.76 %
#
# Saving anchors to the file: anchors.txt
# anchors =  15, 20,  33, 47,  63, 79,  81,138, 152,177, 225,307
# ^C

# %%
# !./darknet detector calc_anchors ../mango_detection/cfg/mango.data -num_of_clusters 6 -width 416 -height 416 -showpause
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#
#  num_of_clusters = 6, width = 416, height = 416
#  read labels from 43370 images
#  loaded 	 image: 43370 	 box: 43370
#  all loaded.
#
#  calculating k-means++ ...
#
#  iterations = 76
#
#
# counters_per_class = 2579, 502, 23587, 15045, 1657
#
#  avg IoU = 64.76 %
#
# Saving anchors to the file: anchors.txt
# anchors =  15, 20,  33, 47,  63, 79,  81,138, 152,177, 225,307
# ^C

# %%
# !./darknet detector calc_anchors ../mango_detection/cfg/mango.data -num_of_clusters 6 -width 416 -height 416 -showpause
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#
#  num_of_clusters = 6, width = 416, height = 416
#  read labels from 6280 images

# %% [markdown]
# # 20210107

# %%
# !./darknet detector train ../mango_detection/cfg/mango.data ../mango_detection/cfg/yolov4-tiny-obj.cfg ../mango_detection/cfg/yolov4-tiny.conv.29 -dont_show
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.137624), count: 4, class_loss = 1.109427, iou_loss = 0.002326, total_loss = 1.111754
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.440134), count: 4, class_loss = 1.110773, iou_loss = 1.028363, total_loss = 2.139136
#  total_bbox = 37147, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.354840), count: 1, class_loss = 0.252548, iou_loss = 0.010909, total_loss = 0.263457
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.332907), count: 7, class_loss = 1.840205, iou_loss = 1.329928, total_loss = 3.170133
#  total_bbox = 37155, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.334369), count: 2, class_loss = 0.455114, iou_loss = 0.005780, total_loss = 0.460894
# ...

# %% [markdown]
# #20210108

# %%
import os

os.path.isfile('/content/drive/My Drive/project/mango/mango_detection/yolo_train/22359.jpg')
# Out:
# False

# %%
# !./darknet detector train ../mango_detection/cfg/mango.data ../mango_detection/cfg/yolov4-tiny-obj_train.cfg ../mango_detection/cfg/weights/yolov4-tiny-obj_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.681281), count: 5, class_loss = 0.792502, iou_loss = 2.061977, total_loss = 2.854480
#  total_bbox = 6436, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.809265), count: 2, class_loss = 0.223660, iou_loss = 0.023648, total_loss = 0.247308
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.653169), count: 6, class_loss = 0.921732, iou_loss = 1.883934, total_loss = 2.805667
#  total_bbox = 6444, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.731070), count: 2, class_loss = 0.271461, iou_loss = 0.063461, total_loss = 0.334922
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.587984), count: 6, class_loss = 0.869632, iou_loss = 4.501102, total_loss = 5.370734
# ...

# %% [markdown]
# #20210108-2

# %%
# !./darknet detector train ../mango_detection/cfg/mango.data ../mango_detection/cfg/yolov4-tiny-obj_train.cfg ../mango_detection/cfg/weights/yolov4-tiny-obj_train_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.704930), count: 2, class_loss = 0.201868, iou_loss = 0.047761, total_loss = 0.249629
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.561040), count: 6, class_loss = 0.736688, iou_loss = 1.383422, total_loss = 2.120110
#  total_bbox = 64184, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.540188), count: 2, class_loss = 0.191118, iou_loss = 0.046649, total_loss = 0.237766
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.583668), count: 6, class_loss = 1.124188, iou_loss = 6.122955, total_loss = 7.247143
#  total_bbox = 64192, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.649794), count: 1, class_loss = 0.105930, iou_loss = 0.026299, total_loss = 0.132229
# ...

# %%
# !./darknet detector train ../mango_detection/cfg/mango.data ../mango_detection/cfg/yolov4-tiny-obj.cfg ../mango_detection/cfg/yolov4-tiny.conv.29 -dont_show

# %%
/content/drive/My Drive/project/mango/darkent/darkent detector train /content/drive/My Drive/project/mango/darkent//mango detection/cfg/mango

# %% [markdown]
# # 20210108-3

# %%
# !./darknet detector train ../mango_detection/cfg/mango.data ../mango_detection/cfg/yolov4-tiny-obj_train.cfg ../mango_detection/cfg/weights/yolov4-tiny-obj_train_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 42267, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.764301), count: 1, class_loss = 0.102067, iou_loss = 0.076850, total_loss = 0.178917
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.657883), count: 7, class_loss = 0.870231, iou_loss = 1.307274, total_loss = 2.177505
#  total_bbox = 42275, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.617535), count: 1, class_loss = 0.131025, iou_loss = 0.026733, total_loss = 0.157758
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.621431), count: 7, class_loss = 0.833669, iou_loss = 5.562071, total_loss = 6.395740
#  total_bbox = 42283, rewritten_bbox = 0.000000 %
# ...
